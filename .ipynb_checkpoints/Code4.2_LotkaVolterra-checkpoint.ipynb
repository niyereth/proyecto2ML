# %% [markdown]
# ### Importing packages
#
# #### Others

# %%
# Used to read the data file
import pandas as pd

# Used in the definition of the model and its initial condition
import numpy as np

# Used for plots other than those generated by the parameter estimation module
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### The module itself

# %%
import PDEparams as pde

# %% [markdown]
# ### Defining the model
#
# We use a classic two-species predator-prey model:
#
# $$\begin{align}
# \frac{\mathrm{d} x}{\mathrm{d} t} &= a\, x(1-x)-b\,x\,y\\
# \frac{\mathrm{d} y}{\mathrm{d} t} &= b\,x\,y-y
# \end{align}$$
#
# Note that the arguments below do not include a spatial grid, since we are dealing with ODEs.

# %%
def LotkaVolterra(z, t, a, b):
    '''The input z corresponds to the current state of the system, z = [x, y]. Since the input is in 1D, no 
    pre-processing is needed.
    
    t is the current time.
    
    a and b correspond to the unknown parameters.
    '''
    
    x, y = z
    
    return [a*x*(1-x)-b*x*y, b*x*y-y]

# %% [markdown]
# Here we specify the functions that define the initial condition for each variable. Since there is no spatial dependence, the initial functions don't take any arguments and return a constant value. The initial condition used for data generation corresponds to $(x,y)=(0.3,0.5)$

# %%
def initial_x():
    return 0.3

def initial_y():
    return 0.5

# %% [markdown]
# ### Using `PDEparams` to estimate parameters
#
# First, we load the data from the `.csv` file.
#
# The data consist of 3 replicates, and have been generated using parameter values $a=3$, $b=1$.
#
# The columns are, in order: $t$, $x$, $y$.

# %%
df = pd.read_csv('LotkaVolterraData.csv')

df.head()
# Out:
#           0         1         2
# 0  0.060606  0.325940  0.469672
# 1  0.060606  0.326474  0.475169
# 2  0.060606  0.317529  0.486987
# 3  0.070707  0.340549  0.492719
# 4  0.070707  0.324513  0.470383

# %% [markdown]
# #### Constructing the `PDEmodel` object.
#
# The inputs are
#
# **Required:**
# 1. The data table `df`.
# 2. The model `LotkaVolterra`.
# 3. The list of initial condition functions.
# 4. The bounds for the parameter values.
#
# **Optional:**
# 1. The parameter names.
# 2. The number of variables: 2. **(Default is 1, this needs to be provided in this case)**
# 3. The number of spatial dimensions: 0. **(Default is 1, this needs to be provided in this case)**
# 4. The number of replicates in the data: 3. **(Default is 1, this needs to be provided in this case)**
# 5. The indices of the measured variables. In this case, the default `None`, since we have data for all 2 variables.
# 6. The function to apply to the output. In this case, the default `None`, since our data is directly $x$ and $y$.

# %%
my_model = pde.PDEmodel(df, LotkaVolterra, [initial_x, initial_y], bounds=[(2, 4), (0.5,2)], 
                        param_names=[r'$a$', r'$b$'], nvars=2, ndims=0, nreplicates=3, obsidx=None, outfunc=None)

# %%
# Printing the initial condition
my_model.initial_condition
# Out:
# array([0.3, 0.5])

# %% [markdown]
# #### Finding the best fit parameters.

# %%
# %%time
my_model.fit()
# Out:
#         $a$       $b$
# 0  2.991859  1.000089
# Wall time: 135 ms

# %%
my_model.best_params
# Out:
#         $a$       $b$
# 0  2.991859  1.000089

# %%
my_model.best_error
# Out:
# 9.411924805246598e-05

# %% [markdown]
# #### Likelihood profiles
#
# We use the default grid of 100 points per parameter.
#
# **Note:** if you see a "widget not found" message, just ignore it; a progress bar will appear when you run the cell below.

# %%
# %%time
my_model.likelihood_profiles()
# Out:
# HBox(children=(IntProgress(value=0, description='parameters', max=2, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='values within parameters', style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='values within parameters', style=ProgressStyle(description_wi…
# Wall time: 16.2 s

# %% [markdown]
# The raw results

# %%
my_model.result_profiles
# Out:
#     parameter     value     error
# 0         $a$  2.000000  0.003617
# 1         $a$  2.020202  0.003437
# 2         $a$  2.040404  0.003264
# 3         $a$  2.060606  0.003099
# 4         $a$  2.080808  0.002942
# 5         $a$  2.101010  0.002792
# 6         $a$  2.121212  0.002649
# 7         $a$  2.141414  0.002513
# 8         $a$  2.161616  0.002385
# 9         $a$  2.181818  0.002263
# 10        $a$  2.202020  0.002149
# 11        $a$  2.222222  0.002041
# 12        $a$  2.242424  0.001940
# 13        $a$  2.262626  0.001841
# 14        $a$  2.282828  0.001746
# 15        $a$  2.303030  0.001653
# 16        $a$  2.323232  0.001562
# 17        $a$  2.343434  0.001475
# 18        $a$  2.363636  0.001390
# 19        $a$  2.383838  0.001308
# 20        $a$  2.404040  0.001228
# 21        $a$  2.424242  0.001151
# 22        $a$  2.444444  0.001077
# 23        $a$  2.464646  0.001006
# 24        $a$  2.484848  0.000937
# 25        $a$  2.505051  0.000871
# 26        $a$  2.525253  0.000807
# 27        $a$  2.545455  0.000747
# 28        $a$  2.565657  0.000689
# 29        $a$  2.585859  0.000634
# ..        ...       ...       ...
# 170       $b$  1.560606  0.002154
# 171       $b$  1.575758  0.002278
# 172       $b$  1.590909  0.002405
# 173       $b$  1.606061  0.002537
# 174       $b$  1.621212  0.002673
# 175       $b$  1.636364  0.002813
# 176       $b$  1.651515  0.002957
# 177       $b$  1.666667  0.003105
# 178       $b$  1.681818  0.003258
# 179       $b$  1.696970  0.003415
# 180       $b$  1.712121  0.003577
# 181       $b$  1.727273  0.003742
# 182       $b$  1.742424  0.003912
# 183       $b$  1.757576  0.004087
# 184       $b$  1.772727  0.004266
# 185       $b$  1.787879  0.004449
# 186       $b$  1.803030  0.004636
# 187       $b$  1.818182  0.004829
# 188       $b$  1.833333  0.005025
# 189       $b$  1.848485  0.005226
# 190       $b$  1.863636  0.005432
# 191       $b$  1.878788  0.005642
# 192       $b$  1.893939  0.005856
# 193       $b$  1.909091  0.006075
# 194       $b$  1.924242  0.006299
# 195       $b$  1.939394  0.006527
# 196       $b$  1.954545  0.006759
# 197       $b$  1.969697  0.006996
# 198       $b$  1.984848  0.007238
# 199       $b$  2.000000  0.007484
#
# [200 rows x 3 columns]

# %% [markdown]
# Visualisation

# %%
my_model.plot_profiles()

# %% [markdown]
# #### Bootstrapping
#
# We use the default 100 repetitions.
#
# **Note:** if you see a "widget not found" message, just ignore it; a progress bar will appear when you run the cell below.

# %%
# %%time
my_model.bootstrap()
# Out:
# HBox(children=(IntProgress(value=0, description='runs', style=ProgressStyle(description_width='initial')), HTM…
#               $a$         $b$
# count  100.000000  100.000000
# mean     2.992403    0.999996
# std      0.009050    0.006274
# min      2.972825    0.981182
# 25%      2.984868    0.995474
# 50%      2.993448    1.000578
# 75%      2.998330    1.004162
# max      3.010242    1.013952
# Wall time: 14.9 s

# %% [markdown]
# The summary

# %%
my_model.bootstrap_summary
# Out:
#               $a$         $b$
# count  100.000000  100.000000
# mean     2.992403    0.999996
# std      0.009050    0.006274
# min      2.972825    0.981182
# 25%      2.984868    0.995474
# 50%      2.993448    1.000578
# 75%      2.998330    1.004162
# max      3.010242    1.013952

# %% [markdown]
# The raw results

# %%
my_model.bootstrap_raw
# Out:
#          $a$       $b$
# 0   2.983070  0.981182
# 1   2.996159  0.997135
# 2   2.987436  0.998808
# 3   3.010099  1.004451
# 4   3.005552  1.010845
# 5   2.979745  0.994750
# 6   2.972825  0.994856
# 7   2.985555  0.992073
# 8   3.006041  1.007574
# 9   2.997883  0.999661
# 10  2.984241  0.991919
# 11  2.998181  1.011888
# 12  2.999989  1.002686
# 13  2.990813  0.999414
# 14  3.010242  0.994135
# 15  2.998285  1.002972
# 16  2.996456  1.005463
# 17  3.005455  1.003058
# 18  2.976850  0.992118
# 19  2.980104  0.992165
# 20  2.994507  1.003504
# 21  2.999339  0.992906
# 22  3.000523  1.009514
# 23  2.990985  0.998569
# 24  2.974471  0.990676
# 25  2.988020  0.995815
# 26  2.996614  0.996502
# 27  2.983964  1.001340
# 28  3.005032  1.010031
# 29  2.995355  1.001812
# ..       ...       ...
# 70  3.009348  1.000735
# 71  2.977263  0.998402
# 72  2.982367  0.995652
# 73  2.998465  0.994566
# 74  2.992539  0.992755
# 75  2.993725  1.003221
# 76  2.980848  0.999493
# 77  2.997918  1.007772
# 78  2.989129  0.993464
# 79  2.989098  0.996877
# 80  2.976260  0.998484
# 81  2.994739  1.004764
# 82  2.989746  1.003452
# 83  2.996874  1.005063
# 84  3.003738  1.008806
# 85  2.994884  1.004957
# 86  2.990100  0.992923
# 87  2.999372  0.997942
# 88  2.992036  0.996280
# 89  2.981549  0.995867
# 90  2.996455  1.001435
# 91  3.005978  0.992627
# 92  2.990675  1.000786
# 93  2.998482  1.001837
# 94  3.008650  1.003213
# 95  2.984746  1.003736
# 96  2.979012  0.999130
# 97  2.974728  0.986745
# 98  2.997138  0.997763
# 99  2.981653  0.994941
#
# [100 rows x 2 columns]

# %% [markdown]
# Visualisation

# %%
my_model.plot_bootstrap()

# %% [markdown]
# ### Only one observed variable
#
# Let us suppose now that we only have data for $y$.

# %%
df2 = df[df.columns[[0,2]]] # x, which we are ignoring, is column 1 in the data table

df2.head()
# Out:
#           0         2
# 0  0.060606  0.469672
# 1  0.060606  0.475169
# 2  0.060606  0.486987
# 3  0.070707  0.492719
# 4  0.070707  0.470383

# %% [markdown]
# #### Constructing the `PDEmodel` object.
#
# The inputs are the same as before, except for the data&mdash;now `df2` instead of `df`&mdash;and `obsidx`, which specifies that we only have data for the 2nd variable in the system. Starting from zero, the corresponding index is 1. Since we only have one observed variable, `obsidx` can be either a number or a list of one element.

# %%
my_model2 = pde.PDEmodel(df2, LotkaVolterra, [initial_x, initial_y], bounds=[(2, 4), (0.5,2)], 
                         param_names=[r'$a$', r'$b$'], nvars=2, ndims=0, nreplicates=3, obsidx=[1], outfunc=None)

# %% [markdown]
# #### Finding the best fit parameters.

# %%
# %%time
my_model2.fit()
# Out:
#         $a$       $b$
# 0  2.854213  1.024769
# Wall time: 122 ms

# %%
my_model2.best_params
# Out:
#         $a$       $b$
# 0  2.854213  1.024769

# %%
my_model2.best_error
# Out:
# 9.183109132123787e-05

# %% [markdown]
# #### Likelihood profiles
#
# **Note:** if you see a "widget not found" message, just ignore it; a progress bar will appear when you run the cell below.

# %%
# %%time
my_model2.likelihood_profiles()
# Out:
# HBox(children=(IntProgress(value=0, description='parameters', max=2, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='values within parameters', style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='values within parameters', style=ProgressStyle(description_wi…
# Wall time: 22.3 s

# %% [markdown]
# The raw results

# %%
my_model2.result_profiles
# Out:
#     parameter     value     error
# 0         $a$  2.000000  0.000102
# 1         $a$  2.020202  0.000101
# 2         $a$  2.040404  0.000101
# 3         $a$  2.060606  0.000100
# 4         $a$  2.080808  0.000100
# 5         $a$  2.101010  0.000099
# 6         $a$  2.121212  0.000099
# 7         $a$  2.141414  0.000098
# 8         $a$  2.161616  0.000098
# 9         $a$  2.181818  0.000097
# 10        $a$  2.202020  0.000097
# 11        $a$  2.222222  0.000096
# 12        $a$  2.242424  0.000096
# 13        $a$  2.262626  0.000096
# 14        $a$  2.282828  0.000095
# 15        $a$  2.303030  0.000095
# 16        $a$  2.323232  0.000095
# 17        $a$  2.343434  0.000095
# 18        $a$  2.363636  0.000094
# 19        $a$  2.383838  0.000094
# 20        $a$  2.404040  0.000094
# 21        $a$  2.424242  0.000094
# 22        $a$  2.444444  0.000093
# 23        $a$  2.464646  0.000093
# 24        $a$  2.484848  0.000093
# 25        $a$  2.505051  0.000093
# 26        $a$  2.525253  0.000093
# 27        $a$  2.545455  0.000093
# 28        $a$  2.565657  0.000093
# 29        $a$  2.585859  0.000092
# ..        ...       ...       ...
# 170       $b$  1.560606  0.000553
# 171       $b$  1.575758  0.000594
# 172       $b$  1.590909  0.000637
# 173       $b$  1.606061  0.000681
# 174       $b$  1.621212  0.000727
# 175       $b$  1.636364  0.000775
# 176       $b$  1.651515  0.000824
# 177       $b$  1.666667  0.000875
# 178       $b$  1.681818  0.000927
# 179       $b$  1.696970  0.000981
# 180       $b$  1.712121  0.001037
# 181       $b$  1.727273  0.001094
# 182       $b$  1.742424  0.001152
# 183       $b$  1.757576  0.001212
# 184       $b$  1.772727  0.001273
# 185       $b$  1.787879  0.001336
# 186       $b$  1.803030  0.001400
# 187       $b$  1.818182  0.001465
# 188       $b$  1.833333  0.001532
# 189       $b$  1.848485  0.001600
# 190       $b$  1.863636  0.001669
# 191       $b$  1.878788  0.001740
# 192       $b$  1.893939  0.001812
# 193       $b$  1.909091  0.001885
# 194       $b$  1.924242  0.001959
# 195       $b$  1.939394  0.002035
# 196       $b$  1.954545  0.002112
# 197       $b$  1.969697  0.002190
# 198       $b$  1.984848  0.002269
# 199       $b$  2.000000  0.002349
#
# [200 rows x 3 columns]

# %% [markdown]
# Visualisation

# %%
my_model2.plot_profiles()

# %% [markdown]
# #### Bootstrapping
#
# **Note:** if you see a "widget not found" message, just ignore it; a progress bar will appear when you run the cell below.

# %%
# %%time
my_model2.bootstrap()
# Out:
# HBox(children=(IntProgress(value=0, description='runs', style=ProgressStyle(description_width='initial')), HTM…
#               $a$         $b$
# count  100.000000  100.000000
# mean     2.921941    1.019296
# std      0.391685    0.068270
# min      2.332665    0.853275
# 25%      2.659627    0.988730
# 50%      2.855565    1.026572
# 75%      3.045344    1.068188
# max      3.997680    1.141100
# Wall time: 11.7 s

# %% [markdown]
# The summary

# %%
my_model2.bootstrap_summary
# Out:
#               $a$         $b$
# count  100.000000  100.000000
# mean     2.921941    1.019296
# std      0.391685    0.068270
# min      2.332665    0.853275
# 25%      2.659627    0.988730
# 50%      2.855565    1.026572
# 75%      3.045344    1.068188
# max      3.997680    1.141100

# %% [markdown]
# The raw results

# %%
my_model2.bootstrap_raw
# Out:
#          $a$       $b$
# 0   2.688228  1.057967
# 1   2.597818  1.077157
# 2   3.480578  0.922850
# 3   3.446875  0.930440
# 4   2.717712  1.058320
# 5   2.544557  1.081170
# 6   2.524206  1.093958
# 7   3.756929  0.887203
# 8   2.663730  1.057020
# 9   2.878736  1.013985
# 10  2.332665  1.141100
# 11  2.547013  1.090068
# 12  2.909300  1.014886
# 13  2.649391  1.080094
# 14  3.506086  0.910832
# 15  2.367286  1.126000
# 16  2.860080  1.032817
# 17  2.532222  1.094948
# 18  3.948276  0.874927
# 19  2.618780  1.077286
# 20  2.737649  1.052349
# 21  2.693050  1.065566
# 22  2.877552  1.040070
# 23  3.952821  0.853275
# 24  2.756213  1.045449
# 25  2.337966  1.138206
# 26  2.807718  1.044457
# 27  2.949446  1.014463
# 28  2.594793  1.081644
# 29  2.858981  1.022555
# ..       ...       ...
# 70  3.010378  0.993391
# 71  2.997350  0.982794
# 72  2.815129  1.036088
# 73  2.977802  0.990410
# 74  2.582665  1.086536
# 75  3.547941  0.894039
# 76  2.417235  1.119837
# 77  2.741182  1.050480
# 78  2.739636  1.053155
# 79  2.556077  1.094377
# 80  3.015026  1.001956
# 81  3.934561  0.859880
# 82  2.887168  1.016966
# 83  2.670892  1.060368
# 84  2.947314  0.991808
# 85  3.083597  0.979537
# 86  2.676345  1.054971
# 87  2.733465  1.049595
# 88  2.786245  1.026331
# 89  2.629400  1.070420
# 90  2.508270  1.112262
# 91  2.913232  1.004242
# 92  3.997680  0.856856
# 93  2.841086  1.026813
# 94  2.744278  1.054285
# 95  2.866058  1.016900
# 96  2.680083  1.056098
# 97  2.590202  1.086824
# 98  2.592663  1.095884
# 99  3.419204  0.916271
#
# [100 rows x 2 columns]

# %% [markdown]
# Visualisation

# %%
my_model2.plot_bootstrap()

# %% [markdown]
# ### Only a function of the variables is observed
#
# Finally, we consider the case when it's not the raw outputs of the system that are observed, but rather a function of them. In this case, let us assume that the observed quantity is
#
# $$\mathcal{F}(x, y) = x\,y$$

# %%
df3 = df[df.columns[[0]]] # we take only the time-points

# We add the new function
df3[r'$\mathcal{F}$'] = df['1']*df['2'] # x and y are, respectively, columns 1 and 2 in the data table

df3.head()
# Out:
#           0  $\mathcal{F}$
# 0  0.060606       0.153085
# 1  0.060606       0.155130
# 2  0.060606       0.154632
# 3  0.070707       0.167795
# 4  0.070707       0.152645

# %% [markdown]
# #### Constructing the `PDEmodel` object.
#
# The inputs are the same as before, except for the data&mdash;now `df3`&mdash;and `outfunc`, which specifies the function to be applied to the outputs before computing the error.

# %%
def F(z):
    x, y = z
    
    return x*y

# %%
my_model3 = pde.PDEmodel(df3, LotkaVolterra, [initial_x, initial_y], bounds=[(2, 4), (0.5,2)], 
                         param_names=[r'$a$', r'$b$'], nvars=2, ndims=0, nreplicates=3, obsidx=None, outfunc=F)

# %% [markdown]
# #### Finding the best fit parameters.

# %%
# %%time
my_model3.fit()
# Out:
#         $a$       $b$
# 0  3.011332  0.962344
# Wall time: 421 ms

# %%
my_model3.best_params
# Out:
#         $a$       $b$
# 0  3.011332  0.962344

# %%
my_model3.best_error
# Out:
# 4.441449169702758e-05

# %% [markdown]
# #### Likelihood profiles
#
# **Note:** if you see a "widget not found" message, just ignore it; a progress bar will appear when you run the cell below.

# %%
# %%time
my_model3.likelihood_profiles()
# Out:
# HBox(children=(IntProgress(value=0, description='parameters', max=2, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='values within parameters', style=ProgressStyle(description_wi…
# HBox(children=(IntProgress(value=0, description='values within parameters', style=ProgressStyle(description_wi…
# Wall time: 1min 1s

# %% [markdown]
# The raw results

# %%
my_model3.result_profiles
# Out:
#     parameter     value     error
# 0         $a$  2.000000  0.002442
# 1         $a$  2.020202  0.002340
# 2         $a$  2.040404  0.002239
# 3         $a$  2.060606  0.002140
# 4         $a$  2.080808  0.002043
# 5         $a$  2.101010  0.001948
# 6         $a$  2.121212  0.001854
# 7         $a$  2.141414  0.001763
# 8         $a$  2.161616  0.001674
# 9         $a$  2.181818  0.001587
# 10        $a$  2.202020  0.001503
# 11        $a$  2.222222  0.001420
# 12        $a$  2.242424  0.001340
# 13        $a$  2.262626  0.001261
# 14        $a$  2.282828  0.001185
# 15        $a$  2.303030  0.001112
# 16        $a$  2.323232  0.001040
# 17        $a$  2.343434  0.000971
# 18        $a$  2.363636  0.000904
# 19        $a$  2.383838  0.000840
# 20        $a$  2.404040  0.000778
# 21        $a$  2.424242  0.000719
# 22        $a$  2.444444  0.000662
# 23        $a$  2.464646  0.000608
# 24        $a$  2.484848  0.000556
# 25        $a$  2.505051  0.000507
# 26        $a$  2.525253  0.000460
# 27        $a$  2.545455  0.000416
# 28        $a$  2.565657  0.000375
# 29        $a$  2.585859  0.000336
# ..        ...       ...       ...
# 170       $b$  1.560606  0.000092
# 171       $b$  1.575758  0.000094
# 172       $b$  1.590909  0.000095
# 173       $b$  1.606061  0.000096
# 174       $b$  1.621212  0.000098
# 175       $b$  1.636364  0.000099
# 176       $b$  1.651515  0.000100
# 177       $b$  1.666667  0.000102
# 178       $b$  1.681818  0.000103
# 179       $b$  1.696970  0.000104
# 180       $b$  1.712121  0.000106
# 181       $b$  1.727273  0.000107
# 182       $b$  1.742424  0.000108
# 183       $b$  1.757576  0.000109
# 184       $b$  1.772727  0.000110
# 185       $b$  1.787879  0.000111
# 186       $b$  1.803030  0.000112
# 187       $b$  1.818182  0.000113
# 188       $b$  1.833333  0.000114
# 189       $b$  1.848485  0.000115
# 190       $b$  1.863636  0.000116
# 191       $b$  1.878788  0.000117
# 192       $b$  1.893939  0.000118
# 193       $b$  1.909091  0.000119
# 194       $b$  1.924242  0.000120
# 195       $b$  1.939394  0.000121
# 196       $b$  1.954545  0.000121
# 197       $b$  1.969697  0.000122
# 198       $b$  1.984848  0.000123
# 199       $b$  2.000000  0.000123
#
# [200 rows x 3 columns]

# %% [markdown]
# Visualisation

# %%
my_model3.plot_profiles()

# %% [markdown]
# #### Bootstrapping
#
# **Note:** if you see a "widget not found" message, just ignore it; a progress bar will appear when you run the cell below.

# %%
# %%time
my_model3.bootstrap()
# Out:
# HBox(children=(IntProgress(value=0, description='runs', style=ProgressStyle(description_width='initial')), HTM…
#               $a$         $b$
# count  100.000000  100.000000
# mean     3.010496    0.962340
# std      0.021826    0.035878
# min      2.962493    0.846855
# 25%      2.998047    0.938988
# 50%      3.011712    0.959632
# 75%      3.021565    0.987687
# max      3.072035    1.039080
# Wall time: 24.3 s

# %% [markdown]
# The summary

# %%
my_model3.bootstrap_summary
# Out:
#               $a$         $b$
# count  100.000000  100.000000
# mean     3.010496    0.962340
# std      0.021826    0.035878
# min      2.962493    0.846855
# 25%      2.998047    0.938988
# 50%      3.011712    0.959632
# 75%      3.021565    0.987687
# max      3.072035    1.039080

# %% [markdown]
# The raw results

# %%
my_model3.bootstrap_raw
# Out:
#          $a$       $b$
# 0   3.005142  0.952657
# 1   3.013850  1.004572
# 2   3.020961  0.978940
# 3   2.983119  1.027271
# 4   3.009114  0.959428
# 5   3.018758  0.953989
# 6   3.013143  0.997037
# 7   3.042316  0.906960
# 8   3.026899  0.937291
# 9   3.072035  0.846855
# 10  3.012601  0.994800
# 11  3.015397  1.004796
# 12  3.015992  1.000187
# 13  3.007722  0.961263
# 14  3.018312  0.961453
# 15  3.009086  0.982114
# 16  2.987978  0.983908
# 17  2.984807  1.027414
# 18  2.993234  0.985260
# 19  3.048629  0.891898
# 20  3.017307  0.938636
# 21  3.015025  0.939249
# 22  2.997533  0.987263
# 23  3.046822  0.915348
# 24  3.015066  0.967916
# 25  3.015251  0.957102
# 26  3.003679  0.982759
# 27  2.982639  0.999388
# 28  3.028669  0.957768
# 29  3.001581  0.981530
# ..       ...       ...
# 70  3.030834  0.917031
# 71  3.001125  0.947429
# 72  2.997670  0.988263
# 73  2.991909  0.978998
# 74  3.035138  0.928903
# 75  2.998421  0.977303
# 76  3.011182  0.969152
# 77  3.016056  0.919438
# 78  3.002810  0.959836
# 79  3.023506  0.929701
# 80  3.016870  0.941952
# 81  3.023092  0.951012
# 82  3.008926  0.951598
# 83  3.008441  0.972625
# 84  2.980258  1.024017
# 85  2.999915  0.988722
# 86  3.000474  1.003950
# 87  2.973092  0.997960
# 88  3.009357  1.004786
# 89  3.037964  0.930211
# 90  3.022795  0.953329
# 91  3.029448  0.939882
# 92  2.973317  1.013603
# 93  2.973933  0.974100
# 94  3.028435  0.949781
# 95  3.040143  0.923992
# 96  2.976403  0.991685
# 97  3.031340  0.931513
# 98  3.012787  0.946080
# 99  3.016781  0.954601
#
# [100 rows x 2 columns]

# %% [markdown]
# Visualisation

# %%
my_model3.plot_bootstrap()
